# %%
import requests
import pandas as pd
import json
from pandas import json_normalize
import datetime

# %%
hq_csv =  "../Stock_data/hangqing/" + "hangqing_A_" + str(curr_time.date()) + ".csv"
df1 = pd.read_csv(hq_csv,dtype={'f12':str})
df1[['f12','f14', 'f13']].head(10)
df1.set_index('f12', inplace=True)
#df1.loc['300820', 'f13']
#df1.index[:10]

for stock_code in df1.index[:]:
    
    market_id = df1.loc[stock_code, 'f13'] #上证是1，深证是0
    if market_id == '0':
        stock_id = stock_code + '2' #上证是1，深证是2
    else:
        stock_id = stock_code + '1' #上证是1，深证是2

    for page_num in range(30):
        try:
            cookies = {
                'em_hq_fls': 'js',
                'pgv_pvi': '9744040960',
                '_qddaz': 'QD.efn5wx.2y13rz.kbiype8t',
                'intellpositionL': '720.95px',
                'cowminicookie': 'true',
                'emshistory': '^%^5B^%^22600519^%^22^%^5D',
                'intellpositionT': '755px',
                'qgqp_b_id': '3b5494631b0d78184891d0de53c4b3d9',
                'st_si': '81244739108722',
                'st_asi': 'delete',
                '_sm_au_c': 'kLQABAOhavxwaGMtlop7idfc5VbaufLUcxaJVNQw0aBAgAAAAXYqAxNyvGhuw4qcGTDpRh0vz6imEFA2Tbt8n3TUV7ks=',
                'st_pvi': '20795103616993',
                'st_sp': '2020-06-17^%^2014^%^3A02^%^3A47',
                'st_inirUrl': 'https^%^3A^%^2F^%^2Fcn.bing.com^%^2F',
                'st_sn': '26',
                'st_psi': '20200629111105268-0-8277370083',
                'HAList': 'a-sh-601865-^%^u798F^%^u83B1^%^u7279^%^2Ca-sz-002813-^%^u8DEF^%^u7545^%^u79D1^%^u6280^%^2Ca-sh-600956-N^%^u65B0^%^u5929^%^2Ca-sh-600519-^%^u8D35^%^u5DDE^%^u8305^%^u53F0^%^2Ca-sz-000858-^%^u4E94^%^20^%^u7CAE^%^20^%^u6DB2^%^2Ca-sz-002129-^%^u4E2D^%^u73AF^%^u80A1^%^u4EFD^%^2Ca-sh-603365-^%^u6C34^%^u661F^%^u5BB6^%^u7EBA^%^2Ca-sh-600918-^%^u4E2D^%^u6CF0^%^u8BC1^%^u5238',
            }

            headers = {
                'Proxy-Connection': 'keep-alive',
                'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.106 Safari/537.36',
                'Accept': '*/*',
                'Referer': 'http://quote.eastmoney.com/f1.html?code=601865^&market=1',
                'Accept-Language': 'en-US,en;q=0.9',
            }

            # params = (
            #     ('pagesize', '144^'),
            #     ('ut', '7eea3edcaed734bea9cbfc24409ed989^'),
            #     ('dpt', 'wzfscj^'),
            #     ('cb', 'jQuery1123002362902683982293_1593400265041^'),
            #     ('pageindex', '17^'),
            #     ('id', '6018651^'),
            #     ('sort', '1^'),
            #     ('ft', '1^'),
            #     ('code', '601865^'),
            #     ('market', '1^'),
            #     ('_', '1593400265053'),
            # )

            params = (
                ('pagesize', '144'),
                ('ut', '7eea3edcaed734bea9cbfc24409ed989'),
                ('dpt', 'wzfscj'),
                #('cb', 'jQuery1123002362902683982293_1593400265041'),
                ('pageindex', str(page_num)),
                ('id', stock_id),
                ('sort', '1'),
                ('ft', '1'),
                ('code', stock_code),
                ('market', market_id),
                ('_', '1593400265053'),
            )


            #print(params)
            response = requests.get('http://push2ex.eastmoney.com/getStockFenShi', headers=headers, params=params, cookies=cookies, verify=False)
            #response = requests.get('http://push2ex.eastmoney.com/getStockFenShi',params=params)
            #response = requests.get('http://push2ex.eastmoney.com/getStockFenShi?pagesize=144&ut=7eea3edcaed734bea9cbfc24409ed989&dpt=wzfscj&pageindex=7&id=6018651&sort=1&ft=1&code=601865&market=1&_=1593400265053')

            #NB. Original query string below. It seems impossible to parse and
            #reproduce query strings 100% accurately so the one below is given
            #in case the reproduced version is not "correct".
            #response = requests.get('http://push2ex.eastmoney.com/getStockFenShi?pagesize=144^&ut=7eea3edcaed734bea9cbfc24409ed989^&dpt=wzfscj^&pageindex=10^&id=6018651^&sort=1^&ft=1^&code=601865^&market=1^&_=1593400265053')
            #response.text


            dict = json.loads(response.text)['data']['data']
            stock_name = json.loads(response.text)['data']['n']
            df = json_normalize(dict)
            #df.tail(10)
            timelst = pd.to_datetime(df['t'],format='%H%M%S')
            #timelst.dt.time
            df['t'] = timelst.dt.time
            df['p'] = df['p']/1000
            curr_time = datetime.datetime.now()
            csv_file_name = "../Stock_data/fenshi/" + "fenshi_" + stock_code + "_" + stock_name + "_" + str(curr_time.date()) + ".csv"

            if page_num == 0:
                df.to_csv(csv_file_name, index=False, encoding="utf_8_sig")
            else:
                df.to_csv(csv_file_name, index=False, header=False, mode='a', encoding="utf_8_sig")
            #print("Page " + str(page_num) + ' stored!')

        except:
            break

    print(stock_code + " " + stock_name + " fenshi stored!")

print("WELL DONE!!!")
# Out:
# 600956 N新天 fenshi stored!
# 603087 N甘李 fenshi stored!
# 688399 硕世生物 fenshi stored!
# 600586 金晶科技 fenshi stored!
# 600207 安彩高科 fenshi stored!
# 002740 爱迪尔 fenshi stored!
# 002640 跨境通 fenshi stored!
# 600552 凯盛科技 fenshi stored!
# 300511 雪榕生物 fenshi stored!
# 300061 旗天科技 fenshi stored!
# 300314 戴维医疗 fenshi stored!
# 300358 楚天科技 fenshi stored!
# 002652 扬子新材 fenshi stored!
# 002813 路畅科技 fenshi stored!
# 000020 深华发Ａ fenshi stored!
# 605166 聚合顺 fenshi stored!
# 603880 南卫股份 fenshi stored!
# 300464 星徽精密 fenshi stored!
# 300842 帝科股份 fenshi stored!
# 300209 天泽信息 fenshi stored!
# 002317 众生药业 fenshi stored!
# 603301 振德医疗 fenshi stored!
# 300260 新莱应材 fenshi stored!
# 300612 宣亚国际 fenshi stored!
# 000799 酒鬼酒 fenshi stored!
# 300755 华致酒行 fenshi stored!
# 300246 宝莱特 fenshi stored!
# 300791 仙乐健康 fenshi stored!
# 603109 神驰机电 fenshi stored!
# 300492 华图山鼎 fenshi stored!
# 603976 正川股份 fenshi stored!
# 601888 中国中免 fenshi stored!
# 601865 福莱特 fenshi stored!
# 300401 花园生物 fenshi stored!
# 600127 金健米业 fenshi stored!
# 300125 聆达股份 fenshi stored!
# 002987 京北方 fenshi stored!
# 300341 麦克奥迪 fenshi stored!
# 600559 老白干酒 fenshi stored!
# 300183 东软载波 fenshi stored!
# 300482 万孚生物 fenshi stored!
# 000820 *ST节能 fenshi stored!
# 000976 华铁股份 fenshi stored!
# 600719 大连热电 fenshi stored!
# 002382 蓝帆医疗 fenshi stored!
# 600638 新黄浦 fenshi stored!
# 002702 海欣食品 fenshi stored!
# 600116 三峡水利 fenshi stored!
# 002776 柏堡龙 fenshi stored!
# 600481 双良节能 fenshi stored!
# 603628 清源股份 fenshi stored!
# 688068 热景生物 fenshi stored!
# 603887 城地股份 fenshi stored!
# 603638 艾迪精密 fenshi stored!
# 000014 沙河股份 fenshi stored!
# 300034 钢研高纳 fenshi stored!
# 000895 双汇发展 fenshi stored!
# 002354 *ST天娱 fenshi stored!
# 603337 杰克股份 fenshi stored!
# 002575 *ST群兴 fenshi stored!
# 002501 *ST利源 fenshi stored!
# 002259 *ST升达 fenshi stored!
# 688363 华熙生物 fenshi stored!
# 603708 家家悦 fenshi stored!
# 600223 鲁商发展 fenshi stored!
# 000504 ST生物 fenshi stored!
# 601778 晶科科技 fenshi stored!
# 002629 *ST仁智 fenshi stored!
# 002028 思源电气 fenshi stored!
# 603697 有友食品 fenshi stored!
# 603936 博敏电子 fenshi stored!
# 600083 *ST博信 fenshi stored!
# 000408 *ST藏格 fenshi stored!
# 600594 益佰制药 fenshi stored!
# 002715 登云股份 fenshi stored!
# 002605 姚记科技 fenshi stored!
# 002585 双星新材 fenshi stored!
# 600238 ST椰岛 fenshi stored!
# 688139 海尔生物 fenshi stored!
# 300227 光韵达 fenshi stored!
# 002044 美年健康 fenshi stored!
# 000972 ST中基 fenshi stored!
# 300412 迦南科技 fenshi stored!
# 000611 *ST天首 fenshi stored!
# 000426 兴业矿业 fenshi stored!
# 600666 ST瑞德 fenshi stored!
# 002400 省广集团 fenshi stored!
# 600247 ST成城 fenshi stored!
# 603439 贵州三力 fenshi stored!
# 002219 *ST恒康 fenshi stored!
# 600225 *ST松江 fenshi stored!
# 688298 东方生物 fenshi stored!
# 002985 北摩高科 fenshi stored!
# 002500 山西证券 fenshi stored!
# 688288 鸿泉物联 fenshi stored!
# 600884 杉杉股份 fenshi stored!
# 600975 新五丰 fenshi stored!
# 600645 中源协和 fenshi stored!
# 002901 大博医疗 fenshi stored!
# 002250 联化科技 fenshi stored!
# 002459 晶澳科技 fenshi stored!
# 002627 宜昌交运 fenshi stored!
# 300274 阳光电源 fenshi stored!
# 688025 杰普特 fenshi stored!
# 601636 旗滨集团 fenshi stored!
# 002210 *ST飞马 fenshi stored!
# 300650 太龙照明 fenshi stored!
# 002650 ST加加 fenshi stored!
# 300347 泰格医药 fenshi stored!
# 603737 DR三棵树 fenshi stored!
# 688089 嘉必优 fenshi stored!
# 600365 通葡股份 fenshi stored!
# 688266 泽璟制药-U fenshi stored!
# 600702 舍得酒业 fenshi stored!
# 300539 横河模具 fenshi stored!
# 300440 运达科技 fenshi stored!
# 002532 新界泵业 fenshi stored!
# 688389 普门科技 fenshi stored!
# 002391 长青股份 fenshi stored!
# 002706 良信电器 fenshi stored!
# 603309 维力医疗 fenshi stored!
# 603666 亿嘉和 fenshi stored!
# 002405 四维图新 fenshi stored!
# 002922 伊戈尔 fenshi stored!
# 688300 联瑞新材 fenshi stored!
# 000004 国农科技 fenshi stored!
# 002335 科华恒盛 fenshi stored!
# 300725 药石科技 fenshi stored!
# 300451 创业慧康 fenshi stored!
# 002772 众兴菌业 fenshi stored!
# 603882 金域医学 fenshi stored!
# 300374 恒通科技 fenshi stored!
# 002880 卫光生物 fenshi stored!
# 300832 新产业 fenshi stored!
# 300527 中船应急 fenshi stored!
# 002218 拓日新能 fenshi stored!
# 603528 多伦科技 fenshi stored!
# 000513 丽珠集团 fenshi stored!
# 600753 东方银星 fenshi stored!
# 603005 晶方科技 fenshi stored!
# 603843 正平股份 fenshi stored!
# 600809 山西汾酒 fenshi stored!
# 002007 华兰生物 fenshi stored!
# 002426 *ST胜利 fenshi stored!
# 000880 潍柴重机 fenshi stored!
# 688026 洁特生物 fenshi stored!
# 000006 深振业Ａ fenshi stored!
# 002399 海普瑞 fenshi stored!
# 300272 开能健康 fenshi stored!
# 000727 *ST东科 fenshi stored!
# 603601 再升科技 fenshi stored!
# 300767 震安科技 fenshi stored!
# 000058 深 赛 格 fenshi stored!
# 603559 中通国脉 fenshi stored!
# 603915 国茂股份 fenshi stored!
# 300721 怡达股份 fenshi stored!
# 688358 祥生医疗 fenshi stored!
# 688196 卓越新能 fenshi stored!
# 600338 西藏珠峰 fenshi stored!
# 688157 松井股份 fenshi stored!
# 300676 华大基因 fenshi stored!
# 300551 古鳌科技 fenshi stored!
# 603996 *ST中新 fenshi stored!
# 300400 劲拓股份 fenshi stored!
# 300463 迈克生物 fenshi stored!
# 600196 复星医药 fenshi stored!
# 603633 徕木股份 fenshi stored!
# 300393 中来股份 fenshi stored!
# 688177 百奥泰-U fenshi stored!
# 002714 牧原股份 fenshi stored!
# 603995 甬金股份 fenshi stored!
# 603069 海汽集团 fenshi stored!
# 002584 西陇科学 fenshi stored!
# 002753 永东股份 fenshi stored!
# 002932 明德生物 fenshi stored!
# 002636 金安国纪 fenshi stored!
# 300525 博思软件 fenshi stored!
# 300206 理邦仪器 fenshi stored!
# 688278 特宝生物 fenshi stored!
# 002414 高德红外 fenshi stored!
# 300531 优博讯 fenshi stored!
# 300812 易天股份 fenshi stored!
# 000090 天健集团 fenshi stored!
# 002859 洁美科技 fenshi stored!
# 600699 均胜电子 fenshi stored!
# 002989 中天精装 fenshi stored!
# 300653 正海生物 fenshi stored!
# 603013 亚普股份 fenshi stored!
# 002041 登海种业 fenshi stored!
# 600025 华能水电 fenshi stored!
# 002727 一心堂 fenshi stored!
# 300802 矩子科技 fenshi stored!
# 603223 恒通股份 fenshi stored!
# 002541 鸿路钢构 fenshi stored!
# 600228 ST昌九 fenshi stored!
# 002556 辉隆股份 fenshi stored!
# 002661 克明面业 fenshi stored!
# 300736 百邦科技 fenshi stored!
# 002747 埃斯顿 fenshi stored!
# 000525 红 太 阳 fenshi stored!
# 600462 *ST九有 fenshi stored!
# 300007 汉威科技 fenshi stored!
# 300719 安达维尔 fenshi stored!
# 600698 ST天雁 fenshi stored!
# 600895 张江高科 fenshi stored!
# 300198 纳川股份 fenshi stored!
# 300729 乐歌股份 fenshi stored!
# 600540 新赛股份 fenshi stored!
# 603038 华立股份 fenshi stored!
# 603922 金鸿顺 fenshi stored!
# 300098 高新兴 fenshi stored!
# 002950 奥美医疗 fenshi stored!
# 601606 长城军工 fenshi stored!
# 002919 名臣健康 fenshi stored!
# 002810 山东赫达 fenshi stored!
# 601998 中信银行 fenshi stored!
# 000012 南  玻Ａ fenshi stored!
# 300778 新城市 fenshi stored!
# 600506 香梨股份 fenshi stored!
# 300094 国联水产 fenshi stored!
# 002437 誉衡药业 fenshi stored!
# 300030 阳普医疗 fenshi stored!
# 300607 拓斯达 fenshi stored!
# 603393 新天然气 fenshi stored!
# 600070 浙江富润 fenshi stored!
# 600119 ST长投 fenshi stored!
# 603650 彤程新材 fenshi stored!
# 002150 通润装备 fenshi stored!
# 300816 艾可蓝 fenshi stored!
# 002432 九安医疗 fenshi stored!
# 002835 同为股份 fenshi stored!
# 603267 鸿远电子 fenshi stored!
# 300460 惠伦晶体 fenshi stored!
# 603458 勘设股份 fenshi stored!
# 002078 太阳纸业 fenshi stored!
# 600215 *ST经开 fenshi stored!
# 000762 西藏矿业 fenshi stored!
# 688126 沪硅产业-U fenshi stored!
# 600285 羚锐制药 fenshi stored!
# 603806 福斯特 fenshi stored!
# 603868 飞科电器 fenshi stored!
# 300381 溢多利 fenshi stored!
# 002212 南洋股份 fenshi stored!
# 300118 东方日升 fenshi stored!
# 600859 王府井 fenshi stored!
# 600075 新疆天业 fenshi stored!
# 000691 亚太实业 fenshi stored!
# 600765 中航重机 fenshi stored!
# 300411 金盾股份 fenshi stored!
# 002284 亚太股份 fenshi stored!
# 600161 天坛生物 fenshi stored!
# 600513 联环药业 fenshi stored!
# 603598 引力传媒 fenshi stored!
# 002282 博深股份 fenshi stored!
# 603676 卫信康 fenshi stored!
# 000953 *ST河化 fenshi stored!
# 300813 泰林生物 fenshi stored!
# 603369 今世缘 fenshi stored!
# 300820 英杰电气 fenshi stored!
# 002821 凯莱英 fenshi stored!
# 300395 菲利华 fenshi stored!
# 603707 健友股份 fenshi stored!
# 300208 青岛中程 fenshi stored!
# 300519 新光药业 fenshi stored!
# 300638 广和通 fenshi stored!
# 002039 黔源电力 fenshi stored!
# 600080 ST金花 fenshi stored!
# 002158 汉钟精机 fenshi stored!
# 600998 九州通 fenshi stored!
# 002681 *ST奋达 fenshi stored!
# 300507 苏奥传感 fenshi stored!
# 002157 正邦科技 fenshi stored!
# 300575 中旗股份 fenshi stored!
# 603788 宁波高发 fenshi stored!
# 600283 钱江水利 fenshi stored!
# 002643 万润股份 fenshi stored!
# 000668 荣丰控股 fenshi stored!
# 603429 集友股份 fenshi stored!
# 002731 萃华珠宝 fenshi stored!
# 300394 天孚通信 fenshi stored!
# 002567 唐人神 fenshi stored!
# 600193 ST创兴 fenshi stored!
# 002022 科华生物 fenshi stored!
# 688520 神州细胞-U fenshi stored!
# 603466 风语筑 fenshi stored!
# 002674 兴业科技 fenshi stored!
# 600988 赤峰黄金 fenshi stored!
# 300591 万里马 fenshi stored!
# 600336 澳柯玛 fenshi stored!
# 002778 高科石化 fenshi stored!
# 002100 天康生物 fenshi stored!
# 603477 振静股份 fenshi stored!
# 002457 青龙管业 fenshi stored!
# 603883 老百姓 fenshi stored!
# 002703 浙江世宝 fenshi stored!
# 002256 *ST兆新 fenshi stored!
# 300147 香雪制药 fenshi stored!
# 600198 大唐电信 fenshi stored!
# 300359 全通教育 fenshi stored!
# 300085 银之杰 fenshi stored!
# 002303 美盈森 fenshi stored!
# 002791 坚朗五金 fenshi stored!
# 002548 金新农 fenshi stored!
# 002330 得利斯 fenshi stored!
# 603970 中农立华 fenshi stored!
# 300318 博晖创新 fenshi stored!
# 000011 深物业A fenshi stored!
# 300669 沪宁股份 fenshi stored!
# 603718 海利生物 fenshi stored!
# 603060 国检集团 fenshi stored!
# 601599 鹿港文化 fenshi stored!
# 300472 新元科技 fenshi stored!
# 688599 天合光能 fenshi stored!
# 603903 中持股份 fenshi stored!
# 000506 中润资源 fenshi stored!
# 000009 中国宝安 fenshi stored!
# 600750 江中药业 fenshi stored!
# 002388 新亚制程 fenshi stored!
# 002884 凌霄泵业 fenshi stored!
# 300562 乐心医疗 fenshi stored!
# 300378 鼎捷软件 fenshi stored!
# 002112 三变科技 fenshi stored!
# 603757 大元泵业 fenshi stored!
# 300404 博济医药 fenshi stored!
# 002635 安洁科技 fenshi stored!
# 002222 福晶科技 fenshi stored!
# 603530 神马电力 fenshi stored!
# 600298 安琪酵母 fenshi stored!
# 300686 智动力 fenshi stored!
# 603893 瑞芯微 fenshi stored!
# 002531 天顺风能 fenshi stored!
# 300110 华仁药业 fenshi stored!
# 603023 威帝股份 fenshi stored!
# 603520 司太立 fenshi stored!
# 300063 天龙集团 fenshi stored!
# 600064 南京高科 fenshi stored!
# 600488 天药股份 fenshi stored!
# 300667 必创科技 fenshi stored!
# 002374 丽鹏股份 fenshi stored!
# 601038 一拖股份 fenshi stored!
# 600658 电子城 fenshi stored!
# 688202 美迪西 fenshi stored!
# 002216 三全食品 fenshi stored!
# 000869 张  裕Ａ fenshi stored!
# 603328 依顿电子 fenshi stored!
# 603639 海利尔 fenshi stored!
# 002370 亚太药业 fenshi stored!
# 603890 春秋电子 fenshi stored!
# 002373 千方科技 fenshi stored!

# %%
t: 时间，p：元*1000，v:手数 bs: 1代表卖方主动(绿色)；2代表买方主动（红色）

# %%
stock_code = '600555'

market_id = '1' #上证是1，深证是0
if market_id == '0':
    stock_id = stock_code + '2' #上证是1，深证是2
else:
    stock_id = stock_code + '1' #上证是1，深证是2

for page_num in range(30):
    try:
        cookies = {
            'em_hq_fls': 'js',
            'pgv_pvi': '9744040960',
            '_qddaz': 'QD.efn5wx.2y13rz.kbiype8t',
            'intellpositionL': '720.95px',
            'cowminicookie': 'true',
            'emshistory': '^%^5B^%^22600519^%^22^%^5D',
            'intellpositionT': '755px',
            'qgqp_b_id': '3b5494631b0d78184891d0de53c4b3d9',
            'st_si': '81244739108722',
            'st_asi': 'delete',
            '_sm_au_c': 'kLQABAOhavxwaGMtlop7idfc5VbaufLUcxaJVNQw0aBAgAAAAXYqAxNyvGhuw4qcGTDpRh0vz6imEFA2Tbt8n3TUV7ks=',
            'st_pvi': '20795103616993',
            'st_sp': '2020-06-17^%^2014^%^3A02^%^3A47',
            'st_inirUrl': 'https^%^3A^%^2F^%^2Fcn.bing.com^%^2F',
            'st_sn': '26',
            'st_psi': '20200629111105268-0-8277370083',
            'HAList': 'a-sh-601865-^%^u798F^%^u83B1^%^u7279^%^2Ca-sz-002813-^%^u8DEF^%^u7545^%^u79D1^%^u6280^%^2Ca-sh-600956-N^%^u65B0^%^u5929^%^2Ca-sh-600519-^%^u8D35^%^u5DDE^%^u8305^%^u53F0^%^2Ca-sz-000858-^%^u4E94^%^20^%^u7CAE^%^20^%^u6DB2^%^2Ca-sz-002129-^%^u4E2D^%^u73AF^%^u80A1^%^u4EFD^%^2Ca-sh-603365-^%^u6C34^%^u661F^%^u5BB6^%^u7EBA^%^2Ca-sh-600918-^%^u4E2D^%^u6CF0^%^u8BC1^%^u5238',
        }

        headers = {
            'Proxy-Connection': 'keep-alive',
            'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.106 Safari/537.36',
            'Accept': '*/*',
            'Referer': 'http://quote.eastmoney.com/f1.html?code=601865^&market=1',
            'Accept-Language': 'en-US,en;q=0.9',
        }

        # params = (
        #     ('pagesize', '144^'),
        #     ('ut', '7eea3edcaed734bea9cbfc24409ed989^'),
        #     ('dpt', 'wzfscj^'),
        #     ('cb', 'jQuery1123002362902683982293_1593400265041^'),
        #     ('pageindex', '17^'),
        #     ('id', '6018651^'),
        #     ('sort', '1^'),
        #     ('ft', '1^'),
        #     ('code', '601865^'),
        #     ('market', '1^'),
        #     ('_', '1593400265053'),
        # )

        params = (
            ('pagesize', '144'),
            ('ut', '7eea3edcaed734bea9cbfc24409ed989'),
            ('dpt', 'wzfscj'),
            #('cb', 'jQuery1123002362902683982293_1593400265041'),
            ('pageindex', str(page_num)),
            ('id', stock_id),
            ('sort', '1'),
            ('ft', '1'),
            ('code', stock_code),
            ('market', market_id),
            ('_', '1593400265053'),
        )


        #print(params)
        response = requests.get('http://push2ex.eastmoney.com/getStockFenShi', headers=headers, params=params, cookies=cookies, verify=False)
        #response = requests.get('http://push2ex.eastmoney.com/getStockFenShi',params=params)
        #response = requests.get('http://push2ex.eastmoney.com/getStockFenShi?pagesize=144&ut=7eea3edcaed734bea9cbfc24409ed989&dpt=wzfscj&pageindex=7&id=6018651&sort=1&ft=1&code=601865&market=1&_=1593400265053')

        #NB. Original query string below. It seems impossible to parse and
        #reproduce query strings 100% accurately so the one below is given
        #in case the reproduced version is not "correct".
        #response = requests.get('http://push2ex.eastmoney.com/getStockFenShi?pagesize=144^&ut=7eea3edcaed734bea9cbfc24409ed989^&dpt=wzfscj^&pageindex=10^&id=6018651^&sort=1^&ft=1^&code=601865^&market=1^&_=1593400265053')
        #response.text


        dict = json.loads(response.text)['data']['data']
        stock_name = json.loads(response.text)['data']['n']
        df = json_normalize(dict)
        #df.tail(10)
        timelst = pd.to_datetime(df['t'],format='%H%M%S')
        #timelst.dt.time
        df['t'] = timelst.dt.time
        df['p'] = df['p']/1000
        curr_time = datetime.datetime.now()
        csv_file_name = "../Stock_data/fenshi/" + "fenshi_" + stock_code + "_" + str(curr_time.date()) + ".csv"

        if page_num == 0:
            df.to_csv(csv_file_name, index=False, encoding="utf_8_sig")
        else:
            df.to_csv(csv_file_name, index=False, header=False, mode='a', encoding="utf_8_sig")
        #print("Page " + str(page_num) + ' stored!')

    except:
        break

print(stock_code + " fenshi stored!")
# Out:
# 600555 fenshi stored!

# %%
stock_code = '002210'

market_id = '0' #上证是1，深证是0
if market_id == '0':
    stock_id = stock_code + '2' #上证是1，深证是2
else:
    stock_id = stock_code + '1' #上证是1，深证是2

page_num = 0
#for page_num in range(30):
    #try:
cookies = {
    'em_hq_fls': 'js',
    'pgv_pvi': '9744040960',
    '_qddaz': 'QD.efn5wx.2y13rz.kbiype8t',
    'intellpositionL': '720.95px',
    'cowminicookie': 'true',
    'emshistory': '^%^5B^%^22600519^%^22^%^5D',
    'intellpositionT': '755px',
    'qgqp_b_id': '3b5494631b0d78184891d0de53c4b3d9',
    'st_si': '81244739108722',
    'st_asi': 'delete',
    '_sm_au_c': 'kLQABAOhavxwaGMtlop7idfc5VbaufLUcxaJVNQw0aBAgAAAAXYqAxNyvGhuw4qcGTDpRh0vz6imEFA2Tbt8n3TUV7ks=',
    'st_pvi': '20795103616993',
    'st_sp': '2020-06-17^%^2014^%^3A02^%^3A47',
    'st_inirUrl': 'https^%^3A^%^2F^%^2Fcn.bing.com^%^2F',
    'st_sn': '26',
    'st_psi': '20200629111105268-0-8277370083',
    'HAList': 'a-sh-601865-^%^u798F^%^u83B1^%^u7279^%^2Ca-sz-002813-^%^u8DEF^%^u7545^%^u79D1^%^u6280^%^2Ca-sh-600956-N^%^u65B0^%^u5929^%^2Ca-sh-600519-^%^u8D35^%^u5DDE^%^u8305^%^u53F0^%^2Ca-sz-000858-^%^u4E94^%^20^%^u7CAE^%^20^%^u6DB2^%^2Ca-sz-002129-^%^u4E2D^%^u73AF^%^u80A1^%^u4EFD^%^2Ca-sh-603365-^%^u6C34^%^u661F^%^u5BB6^%^u7EBA^%^2Ca-sh-600918-^%^u4E2D^%^u6CF0^%^u8BC1^%^u5238',
}

headers = {
    'Proxy-Connection': 'keep-alive',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.106 Safari/537.36',
    'Accept': '*/*',
    'Referer': 'http://quote.eastmoney.com/f1.html?code=601865^&market=1',
    'Accept-Language': 'en-US,en;q=0.9',
}

# params = (
#     ('pagesize', '144^'),
#     ('ut', '7eea3edcaed734bea9cbfc24409ed989^'),
#     ('dpt', 'wzfscj^'),
#     ('cb', 'jQuery1123002362902683982293_1593400265041^'),
#     ('pageindex', '17^'),
#     ('id', '6018651^'),
#     ('sort', '1^'),
#     ('ft', '1^'),
#     ('code', '601865^'),
#     ('market', '1^'),
#     ('_', '1593400265053'),
# )

params = (
    ('pagesize', '144'),
    ('ut', '7eea3edcaed734bea9cbfc24409ed989'),
    ('dpt', 'wzfscj'),
    #('cb', 'jQuery1123002362902683982293_1593400265041'),
    ('pageindex', str(page_num)),
    ('id', stock_id),
    ('sort', '1'),
    ('ft', '1'),
    ('code', stock_code),
    ('market', market_id),
    ('_', '1593400265053'),
)


#print(params)
response = requests.get('http://push2ex.eastmoney.com/getStockFenShi', headers=headers, params=params, cookies=cookies, verify=False)
#response = requests.get('http://push2ex.eastmoney.com/getStockFenShi',params=params)
#response = requests.get('http://push2ex.eastmoney.com/getStockFenShi?pagesize=144&ut=7eea3edcaed734bea9cbfc24409ed989&dpt=wzfscj&pageindex=7&id=6018651&sort=1&ft=1&code=601865&market=1&_=1593400265053')

#NB. Original query string below. It seems impossible to parse and
#reproduce query strings 100% accurately so the one below is given
#in case the reproduced version is not "correct".
#response = requests.get('http://push2ex.eastmoney.com/getStockFenShi?pagesize=144^&ut=7eea3edcaed734bea9cbfc24409ed989^&dpt=wzfscj^&pageindex=10^&id=6018651^&sort=1^&ft=1^&code=601865^&market=1^&_=1593400265053')
#response.text


dict = json.loads(response.text)['data']['data']
stock_name = json.loads(response.text)['data']['n']
df = json_normalize(dict)
#df.tail(10)
timelst = pd.to_datetime(df['t'],format='%H%M%S')
#timelst.dt.time
df['t'] = timelst.dt.time
df['p'] = df['p']/1000
curr_time = datetime.datetime.now()
csv_file_name = "../Stock_data/fenshi/" + "fenshi_" + stock_code + "_" + stock_name + "_" + str(curr_time.date()) + ".csv"

if page_num == 0:
    df.to_csv(csv_file_name, index=False, encoding="utf_8_sig")
else:
    df.to_csv(csv_file_name, index=False, header=False, mode='a', encoding="utf_8_sig")
        #print("Page " + str(page_num) + ' stored!')

    #except:
        #break

print(stock_code + " fenshi stored!")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-8-ad711ab3953e> in <module>
#      91
#      92 if page_num == 0:
# ---> 93     df.to_csv(csv_file_name, index=False, encoding="utf_8_sig")
#      94 else:
#      95     df.to_csv(csv_file_name, index=False, header=False, mode='a', encoding="utf_8_sig")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     186                 self.mode,
#     187                 encoding=self.encoding,
# --> 188                 compression=dict(self.compression_args, method=self.compression),
#     189             )
#     190             close = True
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     426         if encoding:
#     427             # Encoding
# --> 428             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     429         elif is_text:
#     430             # No explicit encoding
#
# OSError: [Errno 22] Invalid argument: '../Stock_data/fenshi/fenshi_002210_*ST飞马_2020-06-30.csv'

# %%
import requests

stock_code = '600555'

market_id = '1' #上证是1，深证是0
if market_id == '0':
    stock_id = stock_code + '2' #上证是1，深证是2
else:
    stock_id = stock_code + '1' #上证是1，深证是2

page_num = 0

cookies = {
    'qgqp_b_id': '3134705a3135c517777b407db2f6a9dd',
    'intellpositionL': '629px',
    '_qddaz': 'QD.rbol34.u54ci4.kbjaw5zs',
    'pgv_pvi': '27656192',
    'cowminicookie': 'true',
    'em_hq_fls': 'js',
    'intellpositionT': '1155px',
    'waptgshowtime': '2020630',
    'st_si': '55956207997043',
    'emshistory': '^%^5B^%^22600555^%^22^%^5D',
    'st_asi': 'delete',
    'HAList': 'a-sh-600555-*ST^%^u6D77^%^u521B^%^2Ca-sz-002223-^%^u9C7C^%^u8DC3^%^u533B^%^u7597^%^2Ca-sz-300059-^%^u4E1C^%^u65B9^%^u8D22^%^u5BCC^%^2Ca-sh-600887-^%^u4F0A^%^u5229^%^u80A1^%^u4EFD^%^2Ca-sh-601816-^%^u4EAC^%^u6CAA^%^u9AD8^%^u94C1^%^2Ca-sz-002264-^%^u65B0^%^u534E^%^u90FD^%^2Ca-sz-002003-^%^u4F1F^%^u661F^%^u80A1^%^u4EFD^%^2Ca-sz-300824-N^%^u5317^%^u9F0E^%^2Ca-sz-300841-^%^u5EB7^%^u534E^%^u751F^%^u7269',
    'st_pvi': '67868090420501',
    'st_sp': '2020-06-17^%^2019^%^3A51^%^3A30',
    'st_inirUrl': 'https^%^3A^%^2F^%^2Fcn.bing.com^%^2F',
    'st_sn': '12',
    'st_psi': '20200630210444371-113200301201-7902862452',
}

headers = {
    'Connection': 'keep-alive',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36',
    'Accept': '*/*',
    'Referer': 'http://quote.eastmoney.com/f1.html?code=600555^&market=1',
    'Accept-Language': 'en-US,en;q=0.9,zh;q=0.8,zh-TW;q=0.7,zh-CN;q=0.6',
}

# params = (
#     ('pagesize', '144^'),
#     ('ut', '7eea3edcaed734bea9cbfc24409ed989^'),
#     ('dpt', 'wzfscj^'),
#     ('cb', 'jQuery112308554476307004573_1593521325739^'),
#     ('pageindex', '0^'),
#     ('id', '6005551^'),
#     ('sort', '1^'),
#     ('ft', '1^'),
#     ('code', '600555^'),
#     ('market', '1^'),
#     ('_', '1593521325778'),
# )

params = (
    ('pagesize', '144'),
    ('ut', '7eea3edcaed734bea9cbfc24409ed989'),
    ('dpt', 'wzfscj'),
    #('cb', 'jQuery112308554476307004573_1593521325739'),
    ('pageindex', str(page_num)),
    ('id', str(stock_id)),
    ('sort', '1'),
    ('ft', '1'),
    ('code', str(stock_code)),
    ('market', str(market_id)),
    ('_', '1593521325778'),
