# %% [markdown]
# # 个股资金流（沪深A股）数据爬取

# %% [markdown]
# 建议每日收盘后爬取，并自动保存在'stock_money_flow_yyyy-mm-dd.csv'文件中

# %%
#                                       '今日主力净流入' '今日超大单净流入'     '今日大单净流入'   '今日中单净流入'  '今日小单净流入'
#    '代码'   '名称'   'f2 最新价''涨跌幅' '净额'  '净占比' '净额'  '净占比'     '净额'   '净占比'  '净额'  '净占比'  '净额'  '净占比'
#1	002603	以岭药业	34.58	9.99%	3.15亿	10.13%	3.98亿	12.79%	-8268.04万	-2.66%	-1.67亿	-5.37%	-1.48亿	-4.76%
#     'f12'  'f14'      'f2'   'f3'    'f62'    'f184'  'f66'    'f69'      'f72'     'f75'    'f78'   'f81'   'f84'    'f87'

# %%
import requests
import pandas as pd
from threading import Timer
import time
import json
from pandas import json_normalize
import matplotlib.pyplot as plt
import datetime

# %%
#需要输入的信息：
stock_id = '002467'
page_num = 1

#-------------------------------------------------------------------------------------

cookies = {
    'cowCookie': 'true',
    'qgqp_b_id': '3134705a3135c517777b407db2f6a9dd',
    'st_si': '99846396600030',
    'st_asi': 'delete',
    'intellpositionL': '629px',
    '_qddaz': 'QD.rbol34.u54ci4.kbjaw5zs',
    'pgv_pvi': '27656192',
    'pgv_si': 's9727063040',
    'intellpositionT': '2149.67px',
    'st_pvi': '67868090420501',
    'st_sp': '2020-06-17^%^2019^%^3A51^%^3A30',
    'st_inirUrl': 'https^%^3A^%^2F^%^2Fcn.bing.com^%^2F',
    'st_sn': '15',
    'st_psi': '20200617201720709-113300300813-6037096727',
}

headers = {
    'Connection': 'keep-alive',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36',
    'Accept': '*/*',
    'Referer': 'http://data.eastmoney.com/zjlx/detail.html',
    'Accept-Language': 'en-US,en;q=0.9,zh;q=0.8,zh-TW;q=0.7,zh-CN;q=0.6',
}

params = (
    ('pn', (str(page_num) + '^')),   #？？^代表第？？页数据
    ('pz', '50^'),
    ('po', '1^'),
    ('np', '1^'),
    ('ut', 'b2884a393a59ad64002292a3e90d46a5^'),
    ('fltt', '2^'),
    ('invt', '2^'),
    ('fid0', 'f4001^'),
    ('fid', 'f62^'),
    ('fs', 'm:0 t:6 f:^!2,m:0 t:13 f:^!2,m:0 t:80 f:^!2,m:1 t:2 f:^!2,m:1 t:23 f:^!2^'),
    ('stat', '1^'),
    ('fields', 'f12,f1,f2,f3,f4,f5,f6,f14,f15,f16,f17,f18,f19,f20,f21,f22,f23,f24,f25,f26,f27,f28,f29,f30,f31,f32,f33,f34,f35,f36,f37,f38,f39,f40,f41,f42,f43,f44,f45,f46,f47,f48,f49,f50,f51,f52,f53,f54,f55,f56,f57,f58,f59,f60,f61^'),
    ('rt', '53079874^'),
    #('cb', 'jQuery18308748778805485093_1592395188934^'),
    ('_', '1592396243859'),
)

response = requests.get('http://push2.eastmoney.com/api/qt/clist/get', headers=headers, params=params, cookies=cookies, verify=False)

#NB. Original query string below. It seems impossible to parse and
#reproduce query strings 100% accurately so the one below is given
#in case the reproduced version is not "correct".
# response = requests.get('http://push2.eastmoney.com/api/qt/clist/get?pn=2^&pz=50^&po=1^&np=1^&ut=b2884a393a59ad64002292a3e90d46a5^&fltt=2^&invt=2^&fid0=f4001^&fid=f62^&fs=m:0+t:6+f:^!2,m:0+t:13+f:^!2,m:0+t:80+f:^!2,m:1+t:2+f:^!2,m:1+t:23+f:^!2^&stat=1^&fields=f12,f14,f2,f3,f62,f184,f66,f69,f72,f75,f78,f81,f84,f87,f204,f205,f124^&rt=53079874^&cb=jQuery18308748778805485093_1592395188934^&_=1592396243859', headers=headers, cookies=cookies, verify=False)
#response.text

dict = json.loads(response.text)['data']['diff']
df = json_normalize(dict)
df2 = df.set_index(['f12'])
df2.loc[stock_id]
# Out:
# f16            7.1
# f17            7.1
# f18           7.09
# f19             13
# f20    10180299246
# f21     8767810035
# f22           0.13
# f23           4.84
# f24           8.88
# f25          40.07
# f26       20100908
# f27              0
# f28              -
# f29              1
# f30          12250
# f31           7.47
# f32           7.48
# f33         -43.38
# f34         784101
# f35         497139
# f36         7138.3
# f37           1.71
# f38      1.361e+09
# f39    1.17217e+09
# f40     2.4713e+08
# f41        -5.8422
# f42    3.64779e+07
# f43     2.8794e+06
# f44    4.10959e+07
# f45    3.56476e+07
# f46        -3.4592
# f47    3.44814e+08
# f48       0.203353
# f49        55.3404
# f50    2.76124e+09
# f51    9.36914e+08
# f52    1.35268e+08
# f53    1.92066e+07
# f54    5.70299e+08
# f55    4.93367e+08
# f56    7.69325e+07
# f57        20.6537
# f58    2.10409e+09
# f59         76.201
# f60    3.13699e+08
# f61       0.230718
# Name: 002467, dtype: object

# %%
#                                       '今日主力净流入' '今日超大单净流入'     '今日大单净流入'   '今日中单净流入'  '今日小单净流入'
#    '代码'   '名称'   'f2 最新价''涨跌幅' '净额'  '净占比' '净额'  '净占比'     '净额'   '净占比'  '净额'  '净占比'  '净额'  '净占比'
#1	002603	以岭药业	34.58	9.99%	3.15亿	10.13%	3.98亿	12.79%	-8268.04万	-2.66%	-1.67亿	-5.37%	-1.48亿	-4.76%
#     'f12'  'f14'      'f2'   'f3'    'f62'    'f184'  'f66'    'f69'      'f72'     'f75'    'f78'   'f81'   'f84'    'f87'

# %%
#需要输入的信息：
stock_id = '002174'
page_num = 1
fi_na_list = []
#i = 1
#-------------------------------------------------------------------------------------
for i in range(0, 500):
    
    cookies = {
        'cowCookie': 'true',
        'qgqp_b_id': '3134705a3135c517777b407db2f6a9dd',
        'st_si': '99846396600030',
        'st_asi': 'delete',
        'intellpositionL': '629px',
        '_qddaz': 'QD.rbol34.u54ci4.kbjaw5zs',
        'pgv_pvi': '27656192',
        'pgv_si': 's9727063040',
        'intellpositionT': '2149.67px',
        'st_pvi': '67868090420501',
        'st_sp': '2020-06-17^%^2019^%^3A51^%^3A30',
        'st_inirUrl': 'https^%^3A^%^2F^%^2Fcn.bing.com^%^2F',
        'st_sn': '15',
        'st_psi': '20200617201720709-113300300813-6037096727',
    }

    headers = {
        'Connection': 'keep-alive',
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36',
        'Accept': '*/*',
        'Referer': 'http://data.eastmoney.com/zjlx/detail.html',
        'Accept-Language': 'en-US,en;q=0.9,zh;q=0.8,zh-TW;q=0.7,zh-CN;q=0.6',
    }

    params = (
        ('pn', (str(page_num) + '^')),   #？？^代表第？？页数据
        ('pz', '50^'),
        ('po', '1^'),
        ('np', '1^'),
        ('ut', 'b2884a393a59ad64002292a3e90d46a5^'),
        ('fltt', '2^'),
        ('invt', '2^'),
        ('fid0', 'f4001^'),
        ('fid', 'f62^'),
        ('fs', 'm:0 t:6 f:^!2,m:0 t:13 f:^!2,m:0 t:80 f:^!2,m:1 t:2 f:^!2,m:1 t:23 f:^!2^'),
        ('stat', '1^'),
        ('fields', ('f12,' + "f" + str(i) + "^")),
        ('rt', '53079874^'),
        #('cb', 'jQuery18308748778805485093_1592395188934^'),
        ('_', '1592396243859'),
    )

    response = requests.get('http://push2.eastmoney.com/api/qt/clist/get', headers=headers, params=params, cookies=cookies, verify=False)

    #NB. Original query string below. It seems impossible to parse and
    #reproduce query strings 100% accurately so the one below is given
    #in case the reproduced version is not "correct".
    # response = requests.get('http://push2.eastmoney.com/api/qt/clist/get?pn=2^&pz=50^&po=1^&np=1^&ut=b2884a393a59ad64002292a3e90d46a5^&fltt=2^&invt=2^&fid0=f4001^&fid=f62^&fs=m:0+t:6+f:^!2,m:0+t:13+f:^!2,m:0+t:80+f:^!2,m:1+t:2+f:^!2,m:1+t:23+f:^!2^&stat=1^&fields=f12,f14,f2,f3,f62,f184,f66,f69,f72,f75,f78,f81,f84,f87,f204,f205,f124^&rt=53079874^&cb=jQuery18308748778805485093_1592395188934^&_=1592396243859', headers=headers, cookies=cookies, verify=False)
    #response.text

    dict = json.loads(response.text)['data']['diff']
    df = json_normalize(dict)
    df2 = df.set_index(['f12'])

    fi = "f" + str(i)
    try:
        print(fi + " : " + str(df2.loc[stock_id][fi]))
    except:
        fi_na_list.append(fi)
        continue


fi_na_list
# Out:
# f1 : 2
# f2 : 25.1
# f3 : 9.99
# f4 : 2.28
# f5 : 558825
# f6 : 1350981008.0
# f7 : 8.33
# f8 : 8.44
# f9 : 15.36
# f10 : 4.37
# f11 : 0.0
# f13 : 0
# f14 : 游族网络
# f15 : 25.1
# f16 : 23.2
# f17 : 23.2
# f18 : 22.82
# f19 : 13
# f20 : 22300686557
# f21 : 16624494646
# f22 : 0.0
# f23 : 4.4
# f24 : 13.22
# f25 : 7.86
# f26 : 20070925
# f27 : 0
# f28 : -
# f29 : 1
# f30 : -15
# f31 : 25.1
# f32 : -
# f33 : 100.0
# f34 : 345768
# f35 : 213075
# f36 : 9695.667803606979
# f37 : 7.14
# f38 : 888473568.0
# f39 : 662330464.0
# f40 : 1211340610.44
# f41 : 45.445600000000006
# f42 : 364577910.46
# f43 : -7652945.94
# f44 : 364222017.59
# f45 : 363067371.81
# f46 : 110.1353
# f47 : 3754477810.74
# f48 : 4.225761960443868
# f49 : 46.1852
# f50 : 9128512690.84
# f51 : 3500952999.29
# f52 : 703741042.55
# f53 : 305671177.58
# f54 : 3905972833.82
# f55 : 2848907025.33
# f56 : 1057065808.49
# f57 : 42.78871012294748
# f58 : 5225378941.82
# f59 : 57.24239116261954
# f60 : 745154289.38
# f61 : 0.838690440975853
# f62 : 221072635.0
# f63 : 33306314.0
# f64 : 411339136.0
# f65 : 134513605.0
# f66 : 276825531.0
# f67 : 30.45
# f68 : 9.96
# f69 : 20.49
# f70 : 344924464.0
# f71 : 400677360.0
# f72 : -55752896.0
# f73 : 25.53
# f74 : 29.66
# f75 : -4.13
# f76 : 338319232.0
# f77 : 474411424.0
# f78 : -136092192.0
# f79 : 25.04
# f80 : 35.11
# f81 : -10.07
# f82 : 223132010.0
# f83 : 308182752.0
# f84 : -85050742.0
# f85 : 16.51
# f86 : 22.81
# f87 : -6.29
# f88 : 1.358
# f89 : 1.234
# f90 : 30.76
# f91 : -0.664
# f92 : -1.421
# f94 : -0.938
# f95 : -2.383
# f97 : 1
# f98 : 1
# f99 : 3
# f100 : 软件服务
# f101 : N泽达
# f102 : 福建板块
# f103 : 网络游戏,转债标的,深成500,融资融券,大数据,手游概念,中证500,股权转让,深股通,电子竞技,华为概念,MSCI中盘,富时概念,标普概念,云游戏,字节概念
# f104 : -
# f105 : -
# f106 : -
# f107 : 2
# f108 : 0
# f109 : 8.47
# f110 : 29.72
# f111 : 0
# f112 : 0.408641725
# f113 : 5.698331118
# f114 : 86.93
# f115 : 49.91
# f116 : -
# f117 : -
# f118 : -
# f119 : -
# f120 : 0
# f121 : -
# f122 : 0
# f123 : -
# f124 : 1592879469
# f125 : 0
# f126 : 0
# f127 : 10.91
# f128 : -
# f129 : 29.9714
# f130 : 6.1963653564453125
# f131 : 23.581594467163086
# f132 : 3598994863.95
# f133 : -
# f134 : -
# f135 : 5222539857.02
# f136 : -
# f137 : 0.0
# f138 : 0.0
# f139 : 4
# f142 : 25.09
# f143 : -
# f144 : 25.1
# f145 : -
# f148 : 1089
# f149 : 9.51
# f152 : 2
# f153 : 3
# f154 : 4
# f160 : 17.56
# f161 : -
# f162 : -
# f163 : 0
# f164 : -78666833.0
# f165 : -1.41
# f166 : 93353007.0
# f167 : 1.67
# f168 : -172019840.0
# f169 : -3.08
# f170 : -29517680.0
# f171 : -0.53
# f172 : 108141822.0
# f173 : 1.94
# f174 : -113077661.0
# f175 : -0.89
# f176 : 24742451.0
# f177 : 0.2
# f178 : -137777440.0
# f179 : -1.09
# f180 : -56587952.0
# f181 : -0.45
# f182 : 169622914.0
# f183 : 1.34
# f184 : 16.39
# f185 : -
# f186 : -
# f187 : -
# f188 : -
# f189 : -
# f190 : 0
# f191 : -
# f192 : 0
# f193 : -
# f194 : 0
# f195 : -
# f196 : -
# f197 : -
# f199 : -
# f200 : 0
# f201 : -
# f202 : 0
# f203 : -
# f204 : -
# f207 : -
# f210 : 0
# f211 : 210122
# f212 : -
# f213 : -
# f214 : 0
# f215 : -
# f216 : 0
# f217 : -
# f218 : -
# f219 : -
# f220 : -
# f221 : 20200331
# f222 : -
# f223 : 1
# f224 : -2.8
# f225 : 91
# f226 : 1646
# f227 : -
# f228 : 134.5
# f229 : 146.824
# f230 : 9.16
# f231 : 3
# f232 : 128074
# f233 : 0
# f234 : 游族转债
# f235 : -
# f236 : -
# f237 : -
# f238 : -
# f239 : -
# f240 : -
# f241 : -
# f242 : -
# f243 : -
# f244 : -
# f245 : -
# f246 : -
# f247 : -
# f248 : -
# f249 : -
# f250 : -
# f251 : -
# f252 : -148877970.0
# f253 : -124371731.0
# f254 : -24506239.0
# f255 : -67177479.0
# f256 : 216055427.0
# f257 : -
# f260 : -
# f263 : 1439
# f264 : 1176
# f265 : BK0737
# f266 : 90
# f267 : 141074236.0
# f268 : 4.41
# f269 : 226530300.0
# f270 : 7.08
# f271 : -85456064.0
# f272 : -2.67
# f273 : -116682864.0
# f274 : -3.64
# f275 : -24391381.0
# f276 : -0.76
# f277 : 25.1
# f278 : -354776660.0
# f279 : -238114388.0
# f280 : -116662272.0
# f281 : 112873376.0
# f282 : 241903284.0
# f292 : 2
# f293 : 5.68
# f294 : -
# f295 : -
# f296 : -
# f297 : 20200623
# f298 : -
# f299 : -
# f300 : -
# f301 : -
# f302 : -
# f303 : -
# f304 : 341.9
# f305 : -
# f306 : 0
# f307 : -
# f308 : 0
# f309 : -
# f310 : -
# f311 : -
# f312 : -
# f313 : -
# f314 : -
# f315 : -
# f316 : -
# f317 : -
# f318 : -
# f319 : -
# f320 : -
# f321 : -
# f322 : -
# f323 : -
# f324 : 100
# f325 : -
# f326 : -
# f327 : -
# f328 : -
# f329 : -
# f330 : 0
# f331 : -
# f332 : 0
# f333 : -
# f334 : -
# f335 : -
# f336 : -
# f337 : -
# f339 : -
# f340 : -
# f341 : -
# f342 : -
# f343 : -
# f344 : -
# f345 : -
# f346 : -
# f347 : -
# f348 : -
# f349 : -
# f350 : 25.1
# f351 : 20.54
# f352 : 24.18
# f353 : 16859444
# f354 : 5583275
# f355 : 347
# f356 : 90
# f357 : 14316541
# f358 : 16562253
# f359 : 1003
# f360 : 1136
# f361 : 14050359
# f362 : 19616242
# f363 : 4096
# f364 : 5686
# f365 : 9259780
# f366 : 12726454
# f367 : 19145
# f368 : 26157
# f369 : 377
# f370 : 1826
# f371 : 1757
# f372 : 845
# ['f0',
#  'f12',
#  'f93',
#  'f96',
#  'f140',
#  'f141',
#  'f146',
#  'f147',
#  'f150',
#  'f151',
#  'f155',
#  'f156',
#  'f157',
#  'f158',
#  'f159',
#  'f198',
#  'f205',
#  'f206',
#  'f208',
#  'f209',
#  'f258',
#  'f259',
#  'f261',
#  'f262',
#  'f283',
#  'f284',
#  'f285',
#  'f286',
#  'f287',
#  'f288',
#  'f289',
#  'f290',
#  'f291',
#  'f338',
#  'f373',
#  'f374',
#  'f375',
#  'f376',
#  'f377',
#  'f378',
#  'f379',
#  'f380',
#  'f381',
#  'f382',
#  'f383',
#  'f384',
#  'f385',
#  'f386',
#  'f387',
#  'f388',
#  'f389',
#  'f390',
#  'f391',
#  'f392',
#  'f393',
#  'f394',
#  'f395',
#  'f396',
#  'f397',
#  'f398',
#  'f399',
#  'f400',
#  'f401',
#  'f402',
#  'f403',
#  'f404',
#  'f405',
#  'f406',
#  'f407',
#  'f408',
#  'f409',
#  'f410',
#  'f411',
#  'f412',
#  'f413',
#  'f414',
#  'f415',
#  'f416',
#  'f417',
#  'f418',
#  'f419',
#  'f420',
#  'f421',
#  'f422',
#  'f423',
#  'f424',
#  'f425',
#  'f426',
#  'f427',
#  'f428',
#  'f429',
#  'f430',
#  'f431',
#  'f432',
#  'f433',
#  'f434',
#  'f435',
#  'f436',
#  'f437',
#  'f438',
#  'f439',
#  'f440',
#  'f441',
#  'f442',
#  'f443',
#  'f444',
#  'f445',
#  'f446',
#  'f447',
#  'f448',
#  'f449',
#  'f450',
#  'f451',
#  'f452',
#  'f453',
#  'f454',
#  'f455',
#  'f456',
#  'f457',
#  'f458',
#  'f459',
#  'f460',
#  'f461',
#  'f462',
#  'f463',
#  'f464',
#  'f465',
#  'f466',
#  'f467',
#  'f468',
#  'f469',
#  'f470',
#  'f471',
#  'f472',
#  'f473',
#  'f474',
#  'f475',
#  'f476',
#  'f477',
#  'f478',
#  'f479',
#  'f480',
#  'f481',
#  'f482',
#  'f483',
#  'f484',
#  'f485',
#  'f486',
#  'f487',
#  'f488',
#  'f489',
#  'f490',
#  'f491',
#  'f492',
#  'f493',
#  'f494',
#  'f495',
#  'f496',
#  'f497',
#  'f498',
#  'f499']

# %%
#需要输入的信息：
stock_id = '002174'
page_num = 1
# i = 95
#-------------------------------------------------------------------------------------

string = ['f0',
 'f93',
 'f96',
 'f140',
 'f141',
 'f146',
 'f147',
 'f150',
 'f151',
 'f155',
 'f156',
 'f157',
 'f158',
 'f159',
 'f198',
 'f205',
 'f206',
 'f208',
 'f209',
 'f258',
 'f259',
 'f261',
 'f262',
 'f283',
 'f284',
 'f285',
 'f286',
 'f287',
 'f288',
 'f289',
 'f290',
 'f291',
 'f338',
 'f373',
 'f374',
 'f375',
 'f376',
 'f377',
 'f378',
 'f379',
 'f380',
 'f381',
 'f382',
 'f383',
 'f384',
 'f385',
 'f386',
 'f387',
 'f388',
 'f389',
 'f390',
 'f391',
 'f392',
 'f393',
 'f394',
 'f395',
 'f396',
 'f397',
 'f398',
 'f399',
 'f400',
 'f401',
 'f402',
 'f403',
 'f404',
 'f405',
 'f406',
 'f407',
 'f408',
 'f409',
 'f410',
 'f411',
 'f412',
 'f413',
 'f414',
 'f415',
 'f416',
 'f417',
 'f418',
 'f419',
 'f420',
 'f421',
 'f422',
 'f423',
 'f424',
 'f425',
 'f426',
 'f427',
 'f428',
 'f429',
 'f430',
 'f431',
 'f432',
 'f433',
 'f434',
 'f435',
 'f436',
 'f437',
 'f438',
 'f439',
 'f440',
 'f441',
 'f442',
 'f443',
 'f444',
 'f445',
 'f446',
 'f447',
 'f448',
 'f449',
 'f450',
 'f451',
 'f452',
 'f453',
 'f454',
 'f455',
 'f456',
 'f457',
 'f458',
 'f459',
 'f460',
 'f461',
 'f462',
 'f463',
 'f464',
 'f465',
 'f466',
 'f467',
 'f468',
 'f469',
 'f470',
 'f471',
 'f472',
 'f473',
 'f474',
 'f475',
 'f476',
 'f477',
 'f478',
 'f479',
 'f480',
 'f481',
 'f482',
 'f483',
 'f484',
 'f485',
 'f486',
 'f487',
 'f488',
 'f489',
 'f490',
 'f491',
 'f492',
 'f493',
 'f494',
 'f495',
 'f496',
 'f497',
 'f498',
 'f499']
list1 = []
for i in range(1,400):
    fi = 'f' + str(i)
    if fi not in string:
        list1.append(fi)
string.append('f' + str(i+1) + '^')
#print(string)

str1 = ",".join(list1)
print(str1)  

cookies = {
    'cowCookie': 'true',
    'qgqp_b_id': '3134705a3135c517777b407db2f6a9dd',
    'st_si': '99846396600030',
    'st_asi': 'delete',
    'intellpositionL': '629px',
    '_qddaz': 'QD.rbol34.u54ci4.kbjaw5zs',
    'pgv_pvi': '27656192',
    'pgv_si': 's9727063040',
    'intellpositionT': '2149.67px',
    'st_pvi': '67868090420501',
    'st_sp': '2020-06-17^%^2019^%^3A51^%^3A30',
    'st_inirUrl': 'https^%^3A^%^2F^%^2Fcn.bing.com^%^2F',
    'st_sn': '15',
    'st_psi': '20200617201720709-113300300813-6037096727',
}

headers = {
    'Connection': 'keep-alive',
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.97 Safari/537.36',
    'Accept': '*/*',
    'Referer': 'http://data.eastmoney.com/zjlx/detail.html',
    'Accept-Language': 'en-US,en;q=0.9,zh;q=0.8,zh-TW;q=0.7,zh-CN;q=0.6',
}

params = (
    ('pn', (str(page_num) + '^')),   #？？^代表第？？页数据
    ('pz', '50^'),
    ('po', '1^'),
    ('np', '1^'),
    ('ut', 'b2884a393a59ad64002292a3e90d46a5^'),
    ('fltt', '2^'),
    ('invt', '2^'),
    ('fid0', 'f4001^'),
    ('fid', 'f62^'),
    ('fs', 'm:0 t:6 f:^!2,m:0 t:13 f:^!2,m:0 t:80 f:^!2,m:1 t:2 f:^!2,m:1 t:23 f:^!2^'),
    ('stat', '1^'),
    ('fields', str1),
    ('rt', '53079874^'),
    #('cb', 'jQuery18308748778805485093_1592395188934^'),
    ('_', '1592396243859'),
)

response = requests.get('http://push2.eastmoney.com/api/qt/clist/get', headers=headers, params=params, cookies=cookies, verify=False)

#NB. Original query string below. It seems impossible to parse and
#reproduce query strings 100% accurately so the one below is given
#in case the reproduced version is not "correct".
# response = requests.get('http://push2.eastmoney.com/api/qt/clist/get?pn=2^&pz=50^&po=1^&np=1^&ut=b2884a393a59ad64002292a3e90d46a5^&fltt=2^&invt=2^&fid0=f4001^&fid=f62^&fs=m:0+t:6+f:^!2,m:0+t:13+f:^!2,m:0+t:80+f:^!2,m:1+t:2+f:^!2,m:1+t:23+f:^!2^&stat=1^&fields=f12,f14,f2,f3,f62,f184,f66,f69,f72,f75,f78,f81,f84,f87,f204,f205,f124^&rt=53079874^&cb=jQuery18308748778805485093_1592395188934^&_=1592396243859', headers=headers, cookies=cookies, verify=False)
#response.text

dict = json.loads(response.text)['data']['diff']
df = json_normalize(dict)
df2 = df.set_index(['f12'])

curr_time = datetime.datetime.now()
csv_file_name = "fdata_define_study" + str(curr_time.date()) + ".csv"
df2.to_csv(csv_file_name, index=True, encoding="utf_8_sig")
df2['f33']
# Out:
# f1,f2,f3,f4,f5,f6,f7,f8,f9,f10,f11,f12,f13,f14,f15,f16,f17,f18,f19,f20,f21,f22,f23,f24,f25,f26,f27,f28,f29,f30,f31,f32,f33,f34,f35,f36,f37,f38,f39,f40,f41,f42,f43,f44,f45,f46,f47,f48,f49,f50,f51,f52,f53,f54,f55,f56,f57,f58,f59,f60,f61,f62,f63,f64,f65,f66,f67,f68,f69,f70,f71,f72,f73,f74,f75,f76,f77,f78,f79,f80,f81,f82,f83,f84,f85,f86,f87,f88,f89,f90,f91,f92,f94,f95,f97,f98,f99,f100,f101,f102,f103,f104,f105,f106,f107,f108,f109,f110,f111,f112,f113,f114,f115,f116,f117,f118,f119,f120,f121,f122,f123,f124,f125,f126,f127,f128,f129,f130,f131,f132,f133,f134,f135,f136,f137,f138,f139,f142,f143,f144,f145,f148,f149,f152,f153,f154,f160,f161,f162,f163,f164,f165,f166,f167,f168,f169,f170,f171,f172,f173,f174,f175,f176,f177,f178,f179,f180,f181,f182,f183,f184,f185,f186,f187,f188,f189,f190,f191,f192,f193,f194,f195,f196,f197,f199,f200,f201,f202,f203,f204,f207,f210,f211,f212,f213,f214,f215,f216,f217,f218,f219,f220,f221,f222,f223,f224,f225,f226,f227,f228,f229,f230,f231,f232,f233,f234,f235,f236,f237,f238,f239,f240,f241,f242,f243,f244,f245,f246,f247,f248,f249,f250,f251,f252,f253,f254,f255,f256,f257,f260,f263,f264,f265,f266,f267,f268,f269,f270,f271,f272,f273,f274,f275,f276,f277,f278,f279,f280,f281,f282,f292,f293,f294,f295,f296,f297,f298,f299,f300,f301,f302,f303,f304,f305,f306,f307,f308,f309,f310,f311,f312,f313,f314,f315,f316,f317,f318,f319,f320,f321,f322,f323,f324,f325,f326,f327,f328,f329,f330,f331,f332,f333,f334,f335,f336,f337,f339,f340,f341,f342,f343,f344,f345,f346,f347,f348,f349,f350,f351,f352,f353,f354,f355,f356,f357,f358,f359,f360,f361,f362,f363,f364,f365,f366,f367,f368,f369,f370,f371,f372
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('f31', 'f33')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-7-863a8c4fb4e1> in <module>
#     234 csv_file_name = "fdata_define_study" + str(curr_time.date()) + ".csv"
#     235 df2.to_csv(csv_file_name, index=True, encoding="utf_8_sig")
# --> 236 df2['f31', 'f33']
#     237
#     238
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('f31', 'f33')
